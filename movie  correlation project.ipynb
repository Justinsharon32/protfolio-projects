# %%
# let's import the packages we will use in this project

import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)



#read  in data
df=pd.read_csv(r'C:\Users\justin\Downloads\movies\movies.csv')

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# 0             Stephen King  Jack Nicholson  United Kingdom  19000000.0
# 1  Henry De Vere Stacpoole  Brooke Shields   United States   4500000.0
# 2           Leigh Brackett     Mark Hamill   United States  18000000.0
# 3             Jim Abrahams     Robert Hays   United States   3500000.0
# 4       Brian Doyle-Murray     Chevy Chase   United States   6000000.0
#
#          gross             company  runtime
# 0   46998772.0        Warner Bros.    146.0
# 1   58853106.0   Columbia Pictures    104.0
# 2  538375067.0           Lucasfilm    124.0
# 3   83453539.0  Paramount Pictures     88.0
# 4   39846344.0      Orion Pictures     98.0

# %%
# see if there is any missing data 
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# name - 0%
# rating - 1%
# genre - 0%
# year - 0%
# released - 0%
# score - 0%
# votes - 0%
# director - 0%
# writer - 0%
# star - 0%
# country - 0%
# budget - 28%
# gross - 2%
# company - 0%
# runtime - 0%

# %%
# Data Types for our columns

print(df.dtypes)
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
# create correct year column
df['year correct'] = df['released'].astype(str).str[:8]
df.head()
# Out:
#    name  rating  genre  year  released  score      votes  director  writer  \
# 0  6587       6      6  1980      1705    8.4   927000.0      2589    4014
# 1  5573       6      1  1980      1492    5.8    65000.0      2269    1632
# 2  5142       4      0  1980      1771    8.7  1200000.0      1111    2567
# 3   286       4      4  1980      1492    7.7   221000.0      1301    2000
# 4  1027       6      4  1980      1543    7.3   108000.0      1054     521
#
#    star  country      budget        gross  company  runtime year correct
# 0  1047       54  19000000.0   46998772.0     2319    146.0         1705
# 1   327       55   4500000.0   58853106.0      731    104.0         1492
# 2  1745       55  18000000.0  538375067.0     1540    124.0         1771
# 3  2246       55   3500000.0   83453539.0     1812     88.0         1492
# 4   410       55   6000000.0   39846344.0     1777     98.0         1543

# %%
df.sort_values(by=['gross'],inplace=False,ascending=False)
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
# ...                                          ...    ...     ...   ...
# 7663                                More to Life    NaN   Drama  2020
# 7664                                 Dream Round    NaN  Comedy  2020
# 7665                               Saving Mbango    NaN   Drama  2020
# 7666                                It's Just Us    NaN   Drama  2020
# 7667                                   Tee em el    NaN  Horror  2020
#
#                                released  score      votes       director  \
# 5445  December 18, 2009 (United States)    7.8  1100000.0  James Cameron
# 7445     April 26, 2019 (United States)    8.4   903000.0  Anthony Russo
# 3045  December 19, 1997 (United States)    7.8  1100000.0  James Cameron
# 6663  December 18, 2015 (United States)    7.8   876000.0    J.J. Abrams
# 7244     April 27, 2018 (United States)    8.4   897000.0  Anthony Russo
# ...                                 ...    ...        ...            ...
# 7663   October 23, 2020 (United States)    3.1       18.0  Joseph Ebanks
# 7664   February 7, 2020 (United States)    4.7       36.0   Dusty Dukatz
# 7665          April 27, 2020 (Cameroon)    5.7       29.0   Nkanya Nkwai
# 7666    October 1, 2020 (United States)    NaN        NaN  James Randall
# 7667    August 19, 2020 (United States)    5.7        7.0   Pereko Mosia
#
#                   writer               star        country       budget  \
# 5445       James Cameron    Sam Worthington  United States  237000000.0
# 7445  Christopher Markus  Robert Downey Jr.  United States  356000000.0
# 3045       James Cameron  Leonardo DiCaprio  United States  200000000.0
# 6663     Lawrence Kasdan       Daisy Ridley  United States  245000000.0
# 7244  Christopher Markus  Robert Downey Jr.  United States  321000000.0
# ...                  ...                ...            ...          ...
# 7663       Joseph Ebanks       Shannon Bond  United States       7000.0
# 7664         Lisa Huston   Michael Saquella  United States          NaN
# 7665        Lynno Lovert       Onyama Laura  United States      58750.0
# 7666       James Randall      Christina Roz  United States      15000.0
# 7667        Pereko Mosia   Siyabonga Mabaso   South Africa          NaN
#
#              gross                    company  runtime year correct
# 5445  2.847246e+09      Twentieth Century Fox    162.0     December
# 7445  2.797501e+09             Marvel Studios    181.0     April 26
# 3045  2.201647e+09      Twentieth Century Fox    194.0     December
# 6663  2.069522e+09                  Lucasfilm    138.0     December
# 7244  2.048360e+09             Marvel Studios    149.0     April 27
# ...            ...                        ...      ...          ...
# 7663           NaN                        NaN     90.0     October
# 7664           NaN  Cactus Blue Entertainment     90.0     February
# 7665           NaN           Embi Productions      NaN     April 27
# 7666           NaN                        NaN    120.0     October
# 7667           NaN                PK 65 Films    102.0     August 1
#
# [7668 rows x 16 columns]

# %%
pd.set_option('display.max_rows',None)

# %%
# scatter plot with budget vs gross revenue

plt.scatter(x=df['budget'],y=df['gross'])
plt.title('budget vs grosss earnings')
plt.xlabel('gross earnings')
plt.ylabel('budget for film')
plt.show()

# %%
# plot budget vs gross using seaborn

sns.regplot(x='budget',y='gross', data=df,scatter_kws={"color":"red"},line_kws={"color":"blue"})
# Out:
# <AxesSubplot:xlabel='budget', ylabel='gross'>

# %%
# lets start looking at correlation

df.corr(method='pearson')
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.097995  0.222945  0.329321  0.257486  0.120811
# score    0.097995  1.000000  0.409182  0.076254  0.186258  0.399451
# votes    0.222945  0.409182  1.000000  0.442429  0.630757  0.309212
# budget   0.329321  0.076254  0.442429  1.000000  0.740395  0.320447
# gross    0.257486  0.186258  0.630757  0.740395  1.000000  0.245216
# runtime  0.120811  0.399451  0.309212  0.320447  0.245216  1.000000

# %%
correlation_matrix=df.corr(method='pearson')
sns.heatmap(correlation_matrix,annot=True)
plt.title('correlation matrix for numeric features')
plt.xlabel('movie features')
plt.ylabel('movie features')
plt.show()

# %%
df_numerized=df
for col_name in df_numerized.columns:
   if(df_numerized[col_name].dtype=='object'):
        df_numerized[col_name] =   df_numerized[col_name].astype('category')
        df_numerized[col_name] = df_numerized[col_name].cat.codes
        
df_numerized.head()
# Out:
#    name  rating  genre  year  released  score      votes  director  writer  \
# 0  6587       6      6  1980      1705    8.4   927000.0      2589    4014
# 1  5573       6      1  1980      1492    5.8    65000.0      2269    1632
# 2  5142       4      0  1980      1771    8.7  1200000.0      1111    2567
# 3   286       4      4  1980      1492    7.7   221000.0      1301    2000
# 4  1027       6      4  1980      1543    7.3   108000.0      1054     521
#
#    star  country      budget        gross  company  runtime  year correct
# 0  1047       54  19000000.0   46998772.0     2319    146.0           787
# 1   327       55   4500000.0   58853106.0      731    104.0           550
# 2  1745       55  18000000.0  538375067.0     1540    124.0           860
# 3  2246       55   3500000.0   83453539.0     1812     88.0           550
# 4   410       55   6000000.0   39846344.0     1777     98.0           607

# %%
correlation_matrix=df_numerized.corr(method='pearson')
sns.heatmap(correlation_matrix,annot=True)
plt.title('correlation matrix for numeric features')
plt.xlabel('movie features')
plt.ylabel('movie features')
plt.show()

# %%
correlation_mat=df_numerized.corr()
corr_pairs=correlation_mat.unstack()
corr_pairs
# Out:
# name          name            1.000000
#               rating         -0.008069
#               genre           0.016355
#               year            0.011453
#               released       -0.011311
#               score           0.017097
#               votes           0.013088
#               director        0.009079
#               writer          0.009081
#               star            0.006472
#               country        -0.010737
#               budget          0.023970
#               gross           0.005533
#               company         0.009211
#               runtime         0.010392
#               year correct   -0.011006
# rating        name           -0.008069
#               rating          1.000000
#               genre           0.072423
#               year            0.008779
#               released        0.016613
#               score          -0.001314
#               votes           0.033225
#               director        0.019483
#               writer         -0.005921
#               star            0.013405
#               country         0.081244
#               budget         -0.176002
#               gross          -0.107339
#               company        -0.032943
#               runtime         0.062145
#               year correct    0.013386
# genre         name            0.016355
#               rating          0.072423
#               genre           1.000000
#               year           -0.081261
#               released        0.029822
#               score           0.027965
#               votes          -0.145307
#               director       -0.015258
#               writer          0.006567
#               star           -0.005477
#               country        -0.037615
#               budget         -0.356564
#               gross          -0.235650
#               company        -0.071067
#               runtime        -0.052711
#               year correct    0.035257
# year          name            0.011453
#               rating          0.008779
#               genre          -0.081261
#               year            1.000000
#               released       -0.000695
#               score           0.097995
#               votes           0.222945
#               director       -0.020795
#               writer         -0.008656
#               star           -0.027242
#               country        -0.070938
#               budget          0.329321
#               gross           0.257486
#               company        -0.010431
#               runtime         0.120811
#               year correct   -0.007952
# released      name           -0.011311
#               rating          0.016613
#               genre           0.029822
#               year           -0.000695
#               released        1.000000
#               score           0.042788
#               votes           0.016097
#               director       -0.001478
#               writer         -0.002404
#               star            0.015777
#               country        -0.020427
#               budget          0.014683
#               gross           0.001659
#               company        -0.010474
#               runtime         0.000868
#               year correct    0.962846
# score         name            0.017097
#               rating         -0.001314
#               genre           0.027965
#               year            0.097995
#               released        0.042788
#               score           1.000000
#               votes           0.409182
#               director        0.009559
#               writer          0.019416
#               star           -0.001609
#               country        -0.133348
#               budget          0.076254
#               gross           0.186258
#               company         0.001030
#               runtime         0.399451
#               year correct    0.038378
# votes         name            0.013088
#               rating          0.033225
#               genre          -0.145307
#               year            0.222945
#               released        0.016097
#               score           0.409182
#               votes           1.000000
#               director        0.000260
#               writer          0.000892
#               star           -0.019282
#               country         0.073625
#               budget          0.442429
#               gross           0.630757
#               company         0.133204
#               runtime         0.309212
#               year correct    0.013810
# director      name            0.009079
#               rating          0.019483
#               genre          -0.015258
#               year           -0.020795
#               released       -0.001478
#               score           0.009559
#               votes           0.000260
#               director        1.000000
#               writer          0.299067
#               star            0.039234
#               country         0.017490
#               budget         -0.012272
#               gross          -0.014441
#               company         0.004404
#               runtime         0.017624
#               year correct   -0.004137
# writer        name            0.009081
#               rating         -0.005921
#               genre           0.006567
#               year           -0.008656
#               released       -0.002404
#               score           0.019416
#               votes           0.000892
#               director        0.299067
#               writer          1.000000
#               star            0.027245
#               country         0.015343
#               budget         -0.039451
#               gross          -0.023519
#               company         0.005646
#               runtime        -0.003511
#               year correct   -0.006649
# star          name            0.006472
#               rating          0.013405
#               genre          -0.005477
#               year           -0.027242
#               released        0.015777
#               score          -0.001609
#               votes          -0.019282
#               director        0.039234
#               writer          0.027245
#               star            1.000000
#               country        -0.012998
#               budget         -0.019589
#               gross          -0.002717
#               company         0.012442
#               runtime         0.010174
#               year correct    0.016266
# country       name           -0.010737
#               rating          0.081244
#               genre          -0.037615
#               year           -0.070938
#               released       -0.020427
#               score          -0.133348
#               votes           0.073625
#               director        0.017490
#               writer          0.015343
#               star           -0.012998
#               country         1.000000
#               budget          0.054063
#               gross           0.092129
#               company         0.095548
#               runtime        -0.078412
#               year correct   -0.023345
# budget        name            0.023970
#               rating         -0.176002
#               genre          -0.356564
#               year            0.329321
#               released        0.014683
#               score           0.076254
#               votes           0.442429
#               director       -0.012272
#               writer         -0.039451
#               star           -0.019589
#               country         0.054063
#               budget          1.000000
#               gross           0.740395
#               company         0.173214
#               runtime         0.320447
#               year correct    0.019464
# gross         name            0.005533
#               rating         -0.107339
#               genre          -0.235650
#               year            0.257486
#               released        0.001659
#               score           0.186258
#               votes           0.630757
#               director       -0.014441
#               writer         -0.023519
#               star           -0.002717
#               country         0.092129
#               budget          0.740395
#               gross           1.000000
#               company         0.154840
#               runtime         0.245216
#               year correct    0.002777
# company       name            0.009211
#               rating         -0.032943
#               genre          -0.071067
#               year           -0.010431
#               released       -0.010474
#               score           0.001030
#               votes           0.133204
#               director        0.004404
#               writer          0.005646
#               star            0.012442
#               country         0.095548
#               budget          0.173214
#               gross           0.154840
#               company         1.000000
#               runtime         0.034402
#               year correct   -0.011508
# runtime       name            0.010392
#               rating          0.062145
#               genre          -0.052711
#               year            0.120811
#               released        0.000868
#               score           0.399451
#               votes           0.309212
#               director        0.017624
#               writer         -0.003511
#               star            0.010174
#               country        -0.078412
#               budget          0.320447
#               gross           0.245216
#               company         0.034402
#               runtime         1.000000
#               year correct   -0.004827
# year correct  name           -0.011006
#               rating          0.013386
#               genre           0.035257
#               year           -0.007952
#               released        0.962846
#               score           0.038378
#               votes           0.013810
#               director       -0.004137
#               writer         -0.006649
#               star            0.016266
#               country        -0.023345
#               budget          0.019464
#               gross           0.002777
#               company        -0.011508
#               runtime        -0.004827
#               year correct    1.000000
# dtype: float64

# %%
sorted_pairs=corr_pairs.sort_values()
sorted_pairs
# Out:
# budget        genre          -0.356564
# genre         budget         -0.356564
# gross         genre          -0.235650
# genre         gross          -0.235650
# budget        rating         -0.176002
# rating        budget         -0.176002
# genre         votes          -0.145307
# votes         genre          -0.145307
# score         country        -0.133348
# country       score          -0.133348
# rating        gross          -0.107339
# gross         rating         -0.107339
# year          genre          -0.081261
# genre         year           -0.081261
# country       runtime        -0.078412
# runtime       country        -0.078412
# company       genre          -0.071067
# genre         company        -0.071067
# year          country        -0.070938
# country       year           -0.070938
# runtime       genre          -0.052711
# genre         runtime        -0.052711
# writer        budget         -0.039451
# budget        writer         -0.039451
# genre         country        -0.037615
# country       genre          -0.037615
# rating        company        -0.032943
# company       rating         -0.032943
# star          year           -0.027242
# year          star           -0.027242
# writer        gross          -0.023519
# gross         writer         -0.023519
# year correct  country        -0.023345
# country       year correct   -0.023345
# director      year           -0.020795
# year          director       -0.020795
# country       released       -0.020427
# released      country        -0.020427
# star          budget         -0.019589
# budget        star           -0.019589
# votes         star           -0.019282
# star          votes          -0.019282
# genre         director       -0.015258
# director      genre          -0.015258
#               gross          -0.014441
# gross         director       -0.014441
# country       star           -0.012998
# star          country        -0.012998
# director      budget         -0.012272
# budget        director       -0.012272
# company       year correct   -0.011508
# year correct  company        -0.011508
# released      name           -0.011311
# name          released       -0.011311
# year correct  name           -0.011006
# name          year correct   -0.011006
# country       name           -0.010737
# name          country        -0.010737
# released      company        -0.010474
# company       released       -0.010474
# year          company        -0.010431
# company       year           -0.010431
# writer        year           -0.008656
# year          writer         -0.008656
# name          rating         -0.008069
# rating        name           -0.008069
# year          year correct   -0.007952
# year correct  year           -0.007952
# writer        year correct   -0.006649
# year correct  writer         -0.006649
# writer        rating         -0.005921
# rating        writer         -0.005921
# star          genre          -0.005477
# genre         star           -0.005477
# year correct  runtime        -0.004827
# runtime       year correct   -0.004827
# director      year correct   -0.004137
# year correct  director       -0.004137
# runtime       writer         -0.003511
# writer        runtime        -0.003511
# star          gross          -0.002717
# gross         star           -0.002717
# released      writer         -0.002404
# writer        released       -0.002404
# star          score          -0.001609
# score         star           -0.001609
# director      released       -0.001478
# released      director       -0.001478
# score         rating         -0.001314
# rating        score          -0.001314
# year          released       -0.000695
# released      year           -0.000695
# votes         director        0.000260
# director      votes           0.000260
# runtime       released        0.000868
# released      runtime         0.000868
# writer        votes           0.000892
# votes         writer          0.000892
# score         company         0.001030
# company       score           0.001030
# gross         released        0.001659
# released      gross           0.001659
# year correct  gross           0.002777
# gross         year correct    0.002777
# director      company         0.004404
# company       director        0.004404
# gross         name            0.005533
# name          gross           0.005533
# company       writer          0.005646
# writer        company         0.005646
# star          name            0.006472
# name          star            0.006472
# genre         writer          0.006567
# writer        genre           0.006567
# year          rating          0.008779
# rating        year            0.008779
# director      name            0.009079
# name          director        0.009079
# writer        name            0.009081
# name          writer          0.009081
#               company         0.009211
# company       name            0.009211
# score         director        0.009559
# director      score           0.009559
# runtime       star            0.010174
# star          runtime         0.010174
# runtime       name            0.010392
# name          runtime         0.010392
# year          name            0.011453
# name          year            0.011453
# company       star            0.012442
# star          company         0.012442
# votes         name            0.013088
# name          votes           0.013088
# rating        year correct    0.013386
# year correct  rating          0.013386
# rating        star            0.013405
# star          rating          0.013405
# votes         year correct    0.013810
# year correct  votes           0.013810
# budget        released        0.014683
# released      budget          0.014683
# writer        country         0.015343
# country       writer          0.015343
# released      star            0.015777
# star          released        0.015777
# released      votes           0.016097
# votes         released        0.016097
# year correct  star            0.016266
# star          year correct    0.016266
# name          genre           0.016355
# genre         name            0.016355
# released      rating          0.016613
# rating        released        0.016613
# name          score           0.017097
# score         name            0.017097
# director      country         0.017490
# country       director        0.017490
# runtime       director        0.017624
# director      runtime         0.017624
# score         writer          0.019416
# writer        score           0.019416
# budget        year correct    0.019464
# year correct  budget          0.019464
# rating        director        0.019483
# director      rating          0.019483
# budget        name            0.023970
# name          budget          0.023970
# writer        star            0.027245
# star          writer          0.027245
# score         genre           0.027965
# genre         score           0.027965
#               released        0.029822
# released      genre           0.029822
# votes         rating          0.033225
# rating        votes           0.033225
# company       runtime         0.034402
# runtime       company         0.034402
# year correct  genre           0.035257
# genre         year correct    0.035257
# score         year correct    0.038378
# year correct  score           0.038378
# director      star            0.039234
# star          director        0.039234
# score         released        0.042788
# released      score           0.042788
# budget        country         0.054063
# country       budget          0.054063
# rating        runtime         0.062145
# runtime       rating          0.062145
# genre         rating          0.072423
# rating        genre           0.072423
# country       votes           0.073625
# votes         country         0.073625
# score         budget          0.076254
# budget        score           0.076254
# country       rating          0.081244
# rating        country         0.081244
# country       gross           0.092129
# gross         country         0.092129
# country       company         0.095548
# company       country         0.095548
# score         year            0.097995
# year          score           0.097995
#               runtime         0.120811
# runtime       year            0.120811
# votes         company         0.133204
# company       votes           0.133204
# gross         company         0.154840
# company       gross           0.154840
# budget        company         0.173214
# company       budget          0.173214
# gross         score           0.186258
# score         gross           0.186258
# year          votes           0.222945
# votes         year            0.222945
# gross         runtime         0.245216
# runtime       gross           0.245216
# year          gross           0.257486
# gross         year            0.257486
# director      writer          0.299067
# writer        director        0.299067
# runtime       votes           0.309212
# votes         runtime         0.309212
# budget        runtime         0.320447
# runtime       budget          0.320447
# budget        year            0.329321
# year          budget          0.329321
# runtime       score           0.399451
# score         runtime         0.399451
# votes         score           0.409182
# score         votes           0.409182
# votes         budget          0.442429
# budget        votes           0.442429
# gross         votes           0.630757
# votes         gross           0.630757
# budget        gross           0.740395
# gross         budget          0.740395
# year correct  released        0.962846
# released      year correct    0.962846
# name          name            1.000000
# company       company         1.000000
# gross         gross           1.000000
# budget        budget          1.000000
# country       country         1.000000
# star          star            1.000000
# writer        writer          1.000000
# director      director        1.000000
# votes         votes           1.000000
# score         score           1.000000
# released      released        1.000000
# year          year            1.000000
# genre         genre           1.000000
# rating        rating          1.000000
# runtime       runtime         1.000000
# year correct  year correct    1.000000
# dtype: float64

# %%
high_corr=sorted_pairs[(sorted_pairs)>0.5]
high_corr
# Out:
# gross         votes           0.630757
# votes         gross           0.630757
# budget        gross           0.740395
# gross         budget          0.740395
# year correct  released        0.962846
# released      year correct    0.962846
# name          name            1.000000
# company       company         1.000000
# gross         gross           1.000000
# budget        budget          1.000000
# country       country         1.000000
# star          star            1.000000
# writer        writer          1.000000
# director      director        1.000000
# votes         votes           1.000000
# score         score           1.000000
# released      released        1.000000
# year          year            1.000000
# genre         genre           1.000000
# rating        rating          1.000000
# runtime       runtime         1.000000
# year correct  year correct    1.000000
# dtype: float64

# %%
# votes and budget have the highest correlation to gross earnings
